# %% [markdown]
# # Algorithmische Datenauswertung in Python - Umwelt-Monitoring-System

# %% [markdown]
# <sub>Jupyter Notebook erstellt von Marc Franke, basierend auf einer Unterrichtseinheit für Java von Daniel Hoherz</sub>
#
# ![Lizensiert unter CC-BY-NC-SA](https://upload.wikimedia.org/wikipedia/commons/5/55/Cc_by-nc-sa_euro_icon.svg)
#
# ----------------

# %% [markdown]
# <p align='center'><img src='data:image/png;base64,...' alt="Bild von Umweltzerstörung" width="500"/></p>

# %% [markdown]
# ## Dringlichkeit von Umweltproblemen

# %% [markdown]
# In der heutigen Zeit stehen wir vor einer Vielzahl von Umweltproblemen, die nicht nur die natürliche Umwelt, sondern auch unsere Gesundheit und Lebensqualität erheblich beeinträchtigen. Diese Probleme sind dringlich und erfordern sofortige Maßnahmen, um die Erde und ihre Bewohner zu schützen.
#
# | Luftverschmutzung (Feinstaub & Smog) | Wasserverschmutzung | Dürren & Klimawandel |
# |--------------------------------------|---------------------|----------------------|
# | Feinstaub ist ein unsichtbarer, aber gefährlicher Schadstoff, der durch den Verkehr, industrielle Emissionen und andere menschliche Aktivitäten in die Luft gelangt. In großen Städten ist die Luftqualität oft stark beeinträchtigt, was zu einer erhöhten Belastung durch Smog führt. Smog ist nicht nur unangenehm, sondern auch gesundheitsschädlich und kann Atemwegserkrankungen, Herzprobleme und andere gesundheitliche Beschwerden verursachen. Besonders gefährdet sind Kinder, ältere Menschen und Menschen mit bestehenden Gesundheitsproblemen. Die Dringlichkeit, die Luftqualität zu verbessern, ist daher von höchster Bedeutung. | Die Verschmutzung von Gewässern stellt ein weiteres ernstes Umweltproblem dar. Industrieabfälle, landwirtschaftliche Chemikalien und Plastikmüll gelangen in unsere Flüsse, Seen und Ozeane. Diese Verschmutzung hat verheerende Auswirkungen auf die Tierwelt und die Ökosysteme. Fische und andere Wasserlebewesen sind zunehmend gefährdet, und die Qualität des Trinkwassers leidet. Der Zugang zu sauberem Wasser ist ein grundlegendes Menschenrecht, und die fortschreitende Wasserverschmutzung gefährdet dieses Recht für Millionen von Menschen weltweit. | Ein weiteres alarmierendes Umweltproblem sind Dürren, die durch den Klimawandel und menschliche Aktivitäten verstärkt werden. In vielen Regionen der Welt sind die Niederschläge unregelmäßig und unzureichend, was zu Wasserknappheit und Ernteausfällen führt. Diese Bedingungen bedrohen nicht nur die Nahrungsmittelproduktion, sondern auch das Überleben von Gemeinschaften, die auf Landwirtschaft angewiesen sind. Die Dringlichkeit, nachhaltige Bewässerungssysteme und landwirtschaftliche Praktiken zu entwickeln, ist daher entscheidend, um die Ernährungssicherheit zu gewährleisten. |

# %% [markdown]
# ### Fazit
# Die Herausforderungen, die durch Feinstaub, Smog, Wasserverschmutzung, Dürren und wenig Regen entstehen, sind
# nicht nur Umweltprobleme, sondern auch soziale und wirtschaftliche Krisen. Es liegt in unserer Verantwortung, diese
# Probleme ernst zu nehmen und sofortige Maßnahmen zu ergreifen. Jeder Einzelne kann einen Beitrag leisten, sei es
# durch umweltfreundliche Entscheidungen im Alltag, die Unterstützung von nachhaltigen Initiativen oder durch das
# Eintreten für politische Veränderungen. Gemeinsam können wir eine saubere, gesunde und nachhaltige Zukunft für
# alle schaffen.
#
# ----------------

# %% [markdown]
# ## Messdaten aufnehmen und auswerten in Python

# %% [markdown]
# <p align='center'><img src='data:image/png;base64,...' alt='Bild von Messstation' width="500"/></p>

# %% [markdown]
# ### Aufgabe 1 (Kurze Austauschphase → Gesamte Lerngruppe)

# %% [markdown]
# Angenommen mehrere Messstationen, die verschiedene Sensoren haben, nemen jeden Tag zu bestimmten Zeiten Temperaturwerte auf und geben diese weiter. Die Temperaturen werden immer
# zu den Zeiten 00 Uhr, 06 Uhr, 12 Uhr und 18 Uhr aufgenommen und sollen gespeichert werden.
# Die Temperaturdaten sollen jederzeit gezielt eingesehen und auch ausgewertet werden können.
# Diskutiert die beiden folgenden Möglichkeiten, die Wert zu speichern.
# 1. Für jede Temperatur wird eine Variable angelegt in der die jeweilige Temperatur gespeichert wird.
# 2. Für jeden Zeitslot wird eine Liste angelegt. Es gibt also eine Liste für jeden der vier Zeitslots.
#
# Erläutert auch, weshalb in diesem Szenario eine Variable in Form einer Liste oder einzelne Variablen überhaupt notwendig sind.

# %% [markdown]
# > Hier doppelt Klicken um eure Antwort einzutippen: <br><br><br><br><br><br><br><br>

# %% [markdown]
# ### Aufgabe 2

# %% [markdown]
# In dieser Aufgabe sollen Temperaturdaten in python in einer Liste gespeichert werden. Je eine
# Messstation hat für 10 verschiedene Schulen eine Temperatur aufgenommen.
#
# Eine leere Liste mit dem Namen "beispielListe" erstellt man in python so:

# %%
beispielListe = []

# %% [markdown]
# Man kann dann mit "append" (englisch für "hinten anfügen") eine Zahl zu der Liste hinzufügen:

# %%
beispielListe.append(23.5)
beispielListe.append(24.3)
beispielListe.append(26.0)
beispielListe.append(24.6)
beispielListe.append(23.1)

# %% [markdown]
# Wenn wir uns alle Zahlen, die in unserer Liste gespeichert sind, anzeigen lassen wollen, können wir den print-Befehl nutzen:

# %%
print(beispielListe)
# Out:
# [23.5, 24.3, 26.0, 24.6, 23.1]

# %% [markdown]
# Die Zahlen stehen in genau der Reihenfolge in der Liste, in der wir sie hinzugefügt haben!

# %% [markdown]
# Wenn wir nur die ersten beiden Zahl in der Liste einzeln wissen wollen, können wir das mit dem index machen:

# %%
print(beispielListe[0])
print(beispielListe[1])
# Out:
# 23.5
# 24.3

# %% [markdown]
# So werden die Zahlen in der Liste nummeriert:
#
# <p align='center'><img src='data:image/png;base64,...' alt="Indizierung der Liste" width="300" />

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ⚠️ Listen werden mit 0 beginnend nummeriert! Die vorderste Zahl ist also die nullte Zahl, dann kommt die erste Zahl, usw.
#
# </div>

# %% [markdown]
# Machmal möchte man aber auch noch einen schönen Text ausgeben:

# %%
print("Das erste Element der Liste ist: " + beispielListe[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print("Das erste Element der Liste ist: " + beispielListe[0])
#
# TypeError: can only concatenate str (not "float") to str

# %% [markdown]
# Hier sehen wir das erste Mal, wie es aussieht, wenn wir in python einen Fehler beim Programmieren gemacht haben.
#
# Aber statt nur zu meckern, versucht python so hilfreich wie möglich zu sein, und sagt uns auf englisch sogar, was wir falsch gemacht haben:
#
# | Aussage von python | Bedeutung / Übersetzung |
# | ------------------ | ----------------------- |
# | <span style="color: red;">TypeError</span>|  Das sagt uns, dass wir irgendwo Texte und Zahlen miteinander vertauscht haben |
# | can only concatenate str (not "float") to str | "Ich kann nur einen Text (englisch: Strings, kurz: str) an einen Text anhängen, nicht eine Kommazahl (englisch: Floating-Point Numbers, kurz: float)" |
#
# python weigert sich also, die Zahl aus der beispielListe an den Text "Das erste Element der Liste ist: " anzuhängen!
#
# Können wir das irgendwie beheben? Ja! Indem wir die Zahl in einen Text umwandeln! Das geht in python ganz einfach mit `str()`:

# %%
str(5.0)
# Out:
# '5.0'

# %% [markdown]
# Wir haben die Zahl 5.0 in den Text 5.0 umgewandelt. python zeigt uns an, dass es ein Text ist, indem die 5.0 in Anführungszeichen gesetzt wird!

# %% [markdown]
# Können für für eine Variable auch irgendwie herausfinden, ob es eine Zahl, ein Text oder eine Liste ist? Ja! Mit dem Befehl `type()`:

# %%
type(5.0)
# Out:
# float

# %%
type("Hallo")
# Out:
# str

# %%
type(beispielListe)
# Out:
# list

# %% [markdown]
# Es gibt auch noch eine andere Datentypen, z.B. ganze Zahlen (englisch: Integer, kurz: int):

# %%
type(5)
# Out:
# int

# %% [markdown]
# Und Wahrheitswerte (das sind eigentlich nur True und False). Auf englisch heißen die booleans, kurz bool

# %%
type(True)
# Out:
# bool

# %% [markdown]
# Das können wir jetzt auch alles in einer sogenannten "Zelle" zusammenfassen, dann ist es übersichtlicher:

# %%
beispielListe = [23.5, 24.3, 26.0, 24.6, 23.1]
print("Die Liste enthält die folgenden Elemente: " + str(beispielListe))
print("Das nullte Element der Liste ist: " + str(beispielListe[0]))
print("Das erste Element der Liste ist: " + str(beispielListe[1]))
# Out:
# Die Liste enthält die folgenden Elemente: [23.5, 24.3, 26.0, 24.6, 23.1]
# Das nullte Element der Liste ist: 23.5
# Das erste Element der Liste ist: 24.3

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ⚠️ Wenn du eine Aufgabe bearbeitest, schreibe deine Programme immer nur in einer Zelle, so wie oben. Dann bleibt dein Code übersichtlich und du es passiert nicht, dass du Teile deines Codes "verlierst"
# </div>

# %% [markdown]
# #### Teil a)
# Erstellt ein Programm, welches die folgenden Anforderungen erfüllt.
#
# • Eine Liste temperaturen soll deklariert (erstellt) und beim Start des Programms komplett geleert werden. Diese Liste soll jeweils die gemessenen Werte um 6 Uhr morgens speichern.
#
# • Die folgenden zehn Temperaturwerte sollen in die Liste eingetragen werden:
#
# 25.0, 27.5, 28.0, 31.0, 33.5, 33.1, 32.0, 33.0, 31.0 und 26.8. (Achtung: Gebt 31.0 und
# nicht 31,0 ein!)

# %%
# Hier dein Programm schreiben:

# %% [markdown]
# #### Teil b)
# Die Messstation soll die gespeicherten Daten auch versenden können. Dies modellieren wir zunächst mit dem print-Befehl:
# Erweitert euer Programm oben so, dass alle gespeicherten Temperaturdaten der Reihenfolge nach ausgegeben werden.

# %% [markdown]
# #### Teil c)
# Für die Ausgabe der Messdaten, nachdem die gespeichert wurden, sind unten zwei Varianten dargestellt:

# %% [markdown]
# |Variante 1|Variante 2|
# |---|----|
# |<pre>print(temperatur[0]) <br>print(temperatur[1]) <br>print(temperatur[2])<br>print(temperatur[3])<br>print(temperatur[4])<br>print(temperatur[5])<br>print(temperatur[6])<br>print(temperatur[7])<br>print(temperatur[8])<br>print(temperatur[9])</pre>|<pre>index = 0<br>solange index < länge von temperatur<br>  print(temperatur[index])<br>  erhöhe index um 1</pre>|

# %% [markdown]
# Beschreibt die Funktionsweise der beiden Varianten.

# %% [markdown]
# > Hier doppelt Klicken um eure Antwort einzutippen: <br><br><br><br><br><br><br><br>

# %% [markdown]
# #### Teil d)
# Um Variante 2 in python umsetzen zu können, brauchen wir die solange-Schleife und eine Möglichkeit, die Länge von temperatur zu ermitteln. Glücklicherweise ist das in python einfach nur auf englisch übersetzt:
#
# solange heißt in python `while():` (Klammern und Doppelpunkt sind wichtig!)
#
# Die Länge von temperatur ermittelt man in python mit `len(temperatur)`. len steht für length
#
# In python sieht Variante 2 also so aus:

# %%
index = 0
while index < len(temperatur):
  print(temperatur[index])
  index = index + 1

# %% [markdown]
# Führe die Zelle aus und schau, ob das Ergebnis passt! Beschreibe in eigenen Worten, was die Zeile `index = index + 1` tut.

# %% [markdown]
# > Hier doppelt Klicken um eure Antwort einzutippen: <br><br><br><br><br><br><br><br>

# %% [markdown]
# #### Teil e)
# Untersucht, welche Änderungen in beiden Varianten notwendig sind, wenn die folgenden Anforderungen umgesetzt werden sollen.
# 1. Die Temperaturen sollen beginnend mit dem letzten rückwärts ausgegeben werden.
# 2. Es soll, beginnend mit der ersten Temperatur, nur jede zweite Temperatur ausgegeben werden.
# Beurteilt, inwiefern eine Umsetzung mit einer Schleife hier Vorteile bietet.

# %% [markdown]
# > Hier doppelt Klicken um eure Antwort einzutippen: <br><br><br><br><br><br><br><br>

# %% [markdown]
# #### Teil f)
# Eine Wissenschaftlerin möchte sich aussuchen können, von welchem Tag sie sich die Temperatur
# anzeigen lässt. Dafür soll sie nach einem Tag
# gefragt werden, gibt dessen Nummer ein (0 = Montag, 1=Dienstag ...) und die Messtation gibt die Temperatur des gewünschten Tages aus.
# Erweitert euer Programm um diese Funktionalität.
# Speichert dieses Notebook unter dem Namen "Temperaturwerte" ab.
#
#
# (optionaler Zusatz) Erweitert euer Programm so, dass es das folgende Problem abfängt: Was ist,
# wenn ein Tag eingegeben wird, den es nicht gibt?

# %% [markdown]
# Den Benutzer kann man mit input("Frage an den Nutzer") nach einer Eingabe fragen. Diese muss man in einer Variable speichern. Zum Beispiel so:

# %%
name = input("Gib deinen Namen ein: ")
print("Hallo " + name)
# Out:
# Hallo Marc

# %%
# Hier dein Programm schreiben:

# %% [markdown]
# ### Aufabe 3

# %% [markdown]
# <p align='center'><img src='data:image/png;base64,...' alt="Bild von Wissenschatlerin vor Wolkenkratzer" width="500"/></p>

# %% [markdown]
# Unsere Wissenschaftlerin möchte nun die vorliegenden Messdaten analysieren. Hierfür möchte sie
# zunächst die Durchschnittstemperaturen der zehn Schulen ermitteln.

# %% [markdown]
# #### Teil a) (Austausch mit benachbarten Personen → Gesprächsphase mit der Lehrkraft)
# Diskutiert, wie ihr hierbei vorgehen könnt.

# %% [markdown]
# > Hier doppelt Klicken um Ergebnis-Notizen einzutippen: <br><br><br><br><br><br><br><br>

# %% [markdown]
# #### Teil b) (Partnerarbeit)
# Deklariert zwei neue Variablen mit den Namen `summe` und `durchschnitt`
# und initialisiert beide Variablen nach dem Programmstart mit dem Wert 0.
# Erstellt das Programm so, dass zunächst die Summe der zehn Temperaturen berechnet wird
# und lasst euch danach den Wert der Summe in einem vernünftigen Satz ausgeben.
# Hierfür könnt ihr auch die folgenden Befehle nutzen:

# %%
summe = summe + ...

# %%
while ...:
    ...

# %%
len(temperatur)

# %%
index = ...

# %%
index = index + ...

# %%
temperatur[...]

# %%
... > ...

# %%
summe

# %%
index

# %%
# Hier dein Programm schreiben:

# %% [markdown]
# Erweitert es anschließend so, dass nach der Berechnung der Summe auch der Durchschnitt berechnet wird. Lasst euch auch diesen in einem vernünftigen Satz ausgeben.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ⚠️ Achte darauf, regelmäßig zu speichern!
# </div>

# %% [markdown]
# ## Bedingungen und Entscheidungen

# %% [markdown]
# <p align='center'><img src='data:image/png;base64,...' alt="Bild von Schülern vor Schulgebäude im Sommer" width="500"/></p>

# %% [markdown]
# Angenommen, ein Reihe von Temperatursensoren misst die Temperaturen an verschiedenen Schulen im Hochsommer.
# Die Temperaturwerte des Programms "Temperaturwerte" sollen dies darstellen.
# Natürlich hoffen die Schülerinnen und Schüler, dass es einen Hitzefrei-Tag gibt, wenn es sehr warm
# ist. Dafür müssen jedoch bestimmte Bedingungen erfüllt sein. Wenn diese Bedingungen erfüllt
# sind, gibt es Hitzefrei.
# Dieses Konzept kennt ihr bereits von den microBITs und Scratch 3. Es gibt zwei Arten von Entscheidungen: Eine bedingte Anweisung und eine Verzweigung.

# %% [markdown]
# |bedingte Anweisung|Verzweigung|
# |------------------|-----------|
# |<p align='center'><img src='data:image/png;base64,...' alt="Scratchblock bedingte Anweisung" width="200"/></p>|<p align='center'><img src='data:image/png;base64,...' alt="Scratchblock Verzweigung" width="300"/></p>|

# %% [markdown]
# In python ist wieder alles auf englisch:

# %%
if 3 + 1 < 2:
    print("Bedingung ist wahr")
else:
    print("Bedingung ist falsch")
# Out:
# Bedingung ist falsch

# %% [markdown]
# ### Aufgabe 4

# %% [markdown]
# Bei python gibt es verschiedene Bedingungen. Bedingungen sind immer "wahr" oder "falsch", nie etwas anderes. Unten seht ihr eine Auswahl solcher Bedingungen.

# %%
3 < 4

# %%
4 > 5

# %%
4 == 4

# %%
4 == 5

# %%
4 != 5

# %%
len(beispielListe) < 10

# %%
True and 3 < 5

# %%
True and False

# %%
3 < 4 or False

# %%
False or False

# %%
not True

# %%
not False

# %% [markdown]
# #### Teil a)

# %% [markdown]
# Tauscht euch darüber aus, wie die einzelnen Bedingungen funktionieren und in welchen Fällen "wahr"
# oder "falsch" geantwortet wird.

# %% [markdown]
# > Hier doppelt Klicken um eure Antwort einzutippen: <br><br><br><br><br><br><br><br>

# %% [markdown]
# Beschreibt den Unterschied zwischen den `temperatur = 10` und `temperatur == 10`

# %% [markdown]
# > Hier doppelt Klicken um eure Antwort einzutippen: <br><br><br><br><br><br><br><br>

# %% [markdown]
# #### Teil b)

# %% [markdown]
# Manchmal will man eine Eingabe des Nutzers in einer Bedingung nutzen:

# %%
name = input("Gib deinen Namen ein: ")
if name == "Alice":
    print("Hallo Alice!")
# Out:
# Hallo Alice!

# %% [markdown]
# Erstelle ein Programm, bei dem der Nutzer eine Temperatur größer als 15 eingeben soll. Das Programm soll "Danke" ausgeben, wenn die Temperatur größer als 15 war, und "Du Trottel" sagen, wenn der User eine zu kleine Temperatur eingegeben hat

# %%
# Hier dein Programm

# %% [markdown]
# Dein Programm wird wahrscheinlich nicht funktionieren. 😇 Woran liegt das? python geht davon aus, dass alle Eingaben vom Nutzer Texte sind. Wenn der Nutzer eine Zahl eingibt, fasst python diese trotzdem als Text auf. Für python hast du in deinem Programm etwas unsinniges getan: Geprüft, ob ein Text größer ist als eine Zahl. Das ist so unsinnig wie zu fragen, ob "hallo" größer als 7 ist.
#
# Wir müssen python expizit sagen, dass die Eingabe vom Nutzer eine Zahl war. Das können wir tun, indem wir die Funktion `int()` benutzen (int ist kurz für Integer, englisch für Ganzzahl). Wenn wir also `int(input())` nutzen, sagen wir python, dass es den Input als Zahl verstehen soll.
#
# Ergänze dies in deinem Programm so, dass es funktioniert.

# %% [markdown]
# ### Aufgabe 5

# %% [markdown]
# Um eine automatisierte Statistik über hitzebedingte Unterrichtsausfälle aufzustellen, werden wir
# die vorliegenden Temperaturdaten entsprechend analysieren.

# %% [markdown]
# #### Teil a)

# %% [markdown]
# Angenommen, die Leitung einer Schule muss den Unterricht ausfallen lassen, sobald eine Temperatur von über 33° C gemessen wird. Allerdings gilt dies nur, wenn es sich um einen Schultag,
# also nicht Samstag oder Sonntag handelt. Dafür soll von einem Programm abgefragt werden, für
# welche Schule die Temperatur geprüft werden soll und zusätzlich, ob es sich um einen Unterrichtstag handelt.
# Begründet, weshalb für diese Situation mindestens eine Variable notwendig ist.

# %% [markdown]
# > Hier doppelt Klicken um eure Antwort einzutippen: <br><br><br><br><br><br><br><br>

# %% [markdown]
# #### Teil b)

# %% [markdown]
# Das Programm soll es nun ermöglichen, dass man gefragt wird, ob es sich um einen Schultag
# oder nicht handelt. Man kann dann mit "ja" oder "nein" antworten.
# Anschließend soll man gefragt werden, für welche Schule man sich interessiert (1 bis 10).
# Dann soll geprüft werden, ob die Bedingungen für einen hitzebedingten Unterrichtsausfall erfüllt
# sind.
# Wenn das so ist, soll eine entsprechende Aussage ausgegeben werden. Wenn das nicht so ist, soll
# ebenfalls eine entsprechende Aussage ausgegeben werden.
# Erweitert euer Programm entsprechend und speichert es ab.

# %%
# Hier sind die Temperaturen, die am selben Tag an unterschiedlichen Schulen gemessen wurden
schulenTemperatur = [32.0, 30.5, 31.0, 29.5, 31.5, 32.5, 33.0, 34.3, 35.0, 27.5, 38.9]

# Hier dein Programm

# %% [markdown]
# #### Teil c)

# %% [markdown]
# Unten sind verschiedene Varianten für die Überprüfung
# von Aufgabenteil b) dargestellt.
# Untersucht, ob die Varianten das Problem lösen und erläutert bei nicht funktionierenden Varianten
# die Fehler.
# Beurteilt, ob eine der funktionierenden Varianten besser ist oder keine Variante einen entscheidenden Vorteil bietet.

# %% [markdown]
# > Hier doppelt Klicken um eure Antwort einzutippen: <br><br><br><br><br><br><br><br>

# %% [markdown]
# ##### Variante 1

# %%
schultag = input("War heute ein Schultag (ja/nein)? ")
schule = int(input("An welcher Schule wurde die Temperatur gemessen? (0 - 10) "))
hitzefrei = False

if schultag == "ja":
    if schulenTemperatur[schule] >= 33.0:
        hitzefrei = True

if hitzefrei:
    print("Die Schüler haben heute hitzefrei!")
else:
    print("Die Schüler haben heute keinen hitzefrei.")

# %% [markdown]
# ##### Variante 2

# %%
schultag = input("War heute ein Schultag (ja/nein)? ")
schule = int(input("An welcher Schule wurde die Temperatur gemessen? (0 - 10) "))
hitzefrei = False

if schultag == "ja":
    if schulenTemperatur[schule] >= 33.0:
        print("Die Schüler haben heute hitzefrei!")
print("Die Schüler haben heute keinen hitzefrei.")

# %% [markdown]
# ##### Variante 3

# %%
schultag = input("War heute ein Schultag (ja/nein)? ")
schule = int(input("An welcher Schule wurde die Temperatur gemessen? (0 - 10) "))

if schulenTemperatur[schule] >= 33.0 and schultag == "ja":
    print("Die Schüler haben heute hitzefrei!")
else:
    print("Die Schüler haben heute keinen hitzefrei.")

# %% [markdown]
# ### Aufgabe 6

# %% [markdown]
# <p align='center'><img src='data:image/png;base64,...' alt="Bild von Wisserschaftlerin im Labor" width="500"/></p>

# %% [markdown]
# Verschiedene Umwelt-Messdaten werden häufig detaillierter analysiert. Dafür müssen verschiedene Algorithmen entwickelt und implementiert werden.
# In dieser Aufgabe werden die vorliegenden Temperaturdaten detaillierter ausgewertet.

# %% [markdown]
# #### a) (Austausch mit benachbarten Personen → Gesprächsphase mit der gesamten Lerngruppe)

# %% [markdown]
# Für eine Statistik soll gezählt werden, an wie vielen Schulen an einem Tag hitzebedingt der Unterricht entfällt.
#
# Diskutiert, wie man hierbei vorgehen kann, wenn die Daten in Form einer Liste gespeichert sind.
# Geht auch darauf ein, ob und wofür weitere Variablen genutzt werden muss.

# %% [markdown]
# > Hier doppelt Klicken um eure Ergebnis-Notizen einzutippen: <br><br><br><br><br><br><br><br>

# %% [markdown]
# ### b) (Partnerarbeit)

# %% [markdown]
# Erweitert euer Programm aus der vorherigen Aufgabe so, dass die Anzahl der Schulen mit hitzebedingtem Unterrichtsentfall gezählt und am Schluss mit einem vernünftigen Satz ausgegeben wird.

# %% [markdown]
# ### c) (Partnerarbeit)

# %% [markdown]
# Es kann auch interessant sein zu prüfen, ob bestimmte Temperaturwerte ungewöhnlich sind. Hierfür kann man z. B. den Mittelwert einer Reihe von Temperaturen berechnen und anschließend prüfen, ob ein anderer Wert ungewöhnlich weit vom Mittelwert abweicht.
#
# Ein besonders bemerkenswerter Temperaturwert ist einer, der um mindestens 2° C vom Durchschnittswert abweicht. Es soll gezählt werden, wie viele der zehn Temperaturwerte um mindestens 2° Celsius vom Mittelwert abweichen und eine entsprechende Ausgabe angezeigt werden.
#
# Erweitert euer Programm um diese Funktionalität.

# %% [markdown]
# #### d) (Partnerarbeit)

# %% [markdown]
# Um Extremereignisse untersuchen zu können, sind häufig besonders hohe und besonders niedrige Werte spannend.
#
# Hierfür kann man zum Beispiel ein Minimum und ein Maximum unter vorliegenden Daten bestimmen.
#
# Dazu werden zwei neue Variablen, max und min, benötigt.
#
# Um z. B. ein Maximum zu bestimmen, setzt man den Wert von max auf das erste Element der Datenliste. Anschließend geht man die Liste schrittweise durch und vergleicht den aktuellen Wert von max mit dem aktuellen Listenelement. Wenn man einen größeren Wert gefunden hat, muss man das Maximum neu setzen.
#
# Erweitert euer Programm so, dass zusätzlich das Maximum und Minimum bestimmt und in vernünftigen Sätzen ausgegeben werden.
#
# Ergänzt euer Programm, sodass auch die Indizes, an denen sich das Maximum und das Minimum befinden, gespeichert werden.

# %% [markdown]
# #### e) (Partnerarbeit)

# %% [markdown]
# Manchmal ist es sinnvoll, Daten sortiert anzuzeigen.
#
# Erweitert euer Programm so, dass das Maximum an die letzte Stelle der Liste gesetzt wird. Es soll den Platz mit dem aktuell letzten Element tauschen.

# %% [markdown]
# #### f) (Partnerarbeit)

# %% [markdown]
# Überlegt euch eine Strategie, wie ihr nach und nach die komplette Liste aufsteigend sortieren könnt.

# %% [markdown]
# > Hier doppelt Klicken um eure Antwort einzutippen: <br><br><br><br><br><br><br><br>

# %% [markdown]
# #### g) (Partnerarbeit) (optional)

# %% [markdown]
# Erweitert euer Programm so, dass die Werte in der Liste einmal aufsteigend und einmal absteigend sortiert werden können.

# %% [markdown]
# ## Übungsaufgaben zu Tracetabellen

# %% [markdown]
# ## Aufgabe 1

# %% [markdown]
# ### a)

# %% [markdown]
# Mithilfe eines Luftfeutigkeitssensors soll die aktuelle Luftfeuchtigkeit gemessen werden. Diese kann einen Wert zwischen 0 und 100 haben.
#
# Manchmal senden die Luftfeutigkeitssensoren falsche Daten, nämlich negative Zahlen. Das folgende Programm soll die Anzahl der falschen Werte in einer Liste ermitteln:

# %%
luftfeuchtigkeit = [45, 50, -5, 0, 70, -1, 80, 90, 100, -3]

anzahlNegativ = 0
aktuell = 0
index = 0

while index < len(luftfeuchtigkeit):
    aktuell = luftfeuchtigkeit[index]
    if aktuell < 0 or aktuell == 0:
        anzahlNegativ = anzahlNegativ + 1
    index = index + 1

# %% [markdown]
# Die folgende Tabelle nennt man Tracetabelle. Eine neue Zeile wird am Ende eines Schleifendurchlaufs der `while`-Schleife ausgefüllt. Am Ende des ersten Durchlaufs wurde bereits
# die erste Zeile ausgefüllt.

# %% [markdown]
# | Schleifendurchlauf | index | aktuell | anzahlNegativ |
# | ------------------ | ----- | ------- | ------------- |
# |                  1 |     1 |      45 |             0 |
# |                    |       |         |               |
# |                    |       |         |               |
# |                    |       |         |               |
# |                    |       |         |               |
# |                    |       |         |               |
# |                    |       |         |               |

# %% [markdown]
# Identifiziere mit Hilfe der Tabelle die Stelle, wo der Algorithmus nicht so arbeitet, wie gewünscht
# und korrigiere den Algorithmus entsprechend.

# %% [markdown]
# ### b)

# %% [markdown]
# Der folgende Algorithmus soll für eine korrekte Liste luftfeuchtigkeit alle Zahlen löschen, die negativ sind.

# %%
luftfeuchtigkeit = [45, 50, -5, 60, 70, -1, 80, 90, 100, -3]

aktuell = 0
index = 0

while index < len(luftfeuchtigkeit):
    aktuell = luftfeuchtigkeit[index]
    if aktuell < 0:
        luftfeuchtigkeit.remove(aktuell)
    index = index + 1

# %% [markdown]
# Identifiziere mit Hilfe der unten abgebildeten Tracetabelle die Stelle(n), wo der Algorithmus nicht
# so arbeitet, wie gewünscht und korrigiere den Algorithmus entsprechend.
# Eine neue Zeile wird am Ende eines Schleifendurchlaufs der while-Schleife ausgefüllt. In der Spalte zahlen soll die komplette Liste nach jedem Schleifendurchlauf eingetragen
# werden

# %% [markdown]
# | Schleifendurchlauf | index | aktuell | `len(`luftfeuchtigkeit`)` | luftfeuchtigkeit |
# | ------------------ | ----- | ------- | --------------------- | ---------------- |
# |                    |       |         |                       |                  |
# |                    |       |         |                       |                  |
# |                    |       |         |                       |                  |
# |                    |       |         |                       |                  |
# |                    |       |         |                       |                  |
# |                    |       |         |                       |                  |
# |                    |       |         |                       |                  |

# %% [markdown]
# ### c)

# %% [markdown]
# Der folgende Algorithmus soll für die korregierte Liste von Luftfeuchtigkeiten den
# Durchschnitt ermitteln.

# %%
luftfeuchtigkeit = [45, 50, 60, 70, 80, 90, 100]

summe = 0
durchschnitt = 0
index = 0

while index == len(luftfeuchtigkeit):
    summe = summe + luftfeuchtigkeit[index]
    index = index + 1

durchschnitt = summe / len(luftfeuchtigkeit)

print("Der Durchschnitt der Luftfeuchtigkeit beträgt: " + str(durchschnitt) + "%")
# Out:
# Der Durchschnitt der Luftfeuchtigkeit beträgt: 0.0%

# %% [markdown]
# Identifiziere mit Hilfe der unten abgebildeten Tracetabelle die Stelle(n), wo der Algorithmus nicht
# so arbeitet, wie gewünscht und korrigiere den Algorithmus entsprechend.
# Eine neue Zeile wird am Ende eines Schleifendurchlaufs der while-Schleife ausge-
# füllt. Außerdem soll eine Zeile am Ende des Programms ausgefüllt werden.

# %% [markdown]
# | Schleifendurchlauf | index | summe   | durchschnitt |
# | ------------------ | ----- | ------- | ------------ |
# |                    |       |         |              |
# |                    |       |         |              |
# |                    |       |         |              |
# |                    |       |         |              |
# |                    |       |         |              |
# |                    |       |         |              |
# |                    |       |         |              |

# %% [markdown]
# #### e)

# %% [markdown]
# Es liegen zwei Listen vor. In der Liste waren sind die Namen verschiedener Schulen gespeichert. In einer
# zweiten Liste mengen sind die dazugehörigen Luftfeuchtigkeiten gespeichert. Eine Schule am Index i
# der Liste `schulen` hat eine gemessene Luftfeuchtigkeit am Index i der Liste `luftfeuchtigkeiten`.
#
# Der folgende Algorithmus soll überprüfen, ob eine bestimmte Schule vorhanden ist. Wenn das
# der Fall ist, wird die Luftfeuchtigkeit ausgegeben. Wenn nicht, wird es die Schule am Ende der Liste `schulen` eingefügt und eine vom Nutzer abgefragte Luftfeuchtigkeit in `luftfeuchtigkeiten` gespeichert.

# %%
schulen = ["Gymnasium in der Wüste", "Carolinum", "Ratsgymnasium"]
luftfeuchtigkeiten = [30, 45, 50]

gefunden = True
gesuchteSchule = input("Gib den Namen der gesuchten Schule ein: ")

index = 0
while index < len(schulen):
    if schulen[index] == gesuchteSchule:
        print("Die Luftfeuchtigkeit an der " + gesuchteSchule + " beträgt " + str(luftfeuchtigkeiten[index]) + "%.")
        gefunden = True
    index += 1

if not gefunden:
    schulen.append(gesuchteSchule)
    neueLuftfeuchtigkeit = input("Gib die Luftfeuchtigkeit an der " + gesuchteSchule + " ein: ")
    luftfeuchtigkeiten.append(int(neueLuftfeuchtigkeit))

# %% [markdown]
# Identifiziere mit Hilfe der unten abgebildeten Tracetabelle die Stelle(n), wo der Algorithmus nicht
# so arbeitet, wie gewünscht und korrigiere den Algorithmus entsprechend. Hierfür kannst du einmal
# eine Tracetabelle für den Fall, dass "Carolinum" gesucht und eine zweite Tabelle für den Fall, dass "EMR" gesucht wird, erstellen.
#
# Eine neue Zeile wird am Ende eines Schleifendurchlaufs der while-Schleife ausge-
# füllt. Außerdem noch eine Zeile am Ende des Programms.

# %% [markdown]
# Tracetabelle für "Carolinum":

# %% [markdown]
# | Schleifendurchlauf | index | gesucht | gefunden |        waren                  |          mengen          |
# | ------------------ | ----- | ------- | -------- | ----------------------------- | ------------------------ |
# |                    |       |         |          |                               |                          |
# |                    |       |         |          |                               |                          |
# |                    |       |         |          |                               |                          |
# |                    |       |         |          |                               |                          |
# |                    |       |         |          |                               |                          |
# |                    |       |         |          |                               |                          |
# |                    |       |         |          |                               |                          |
# |                    |       |         |          |                               |                          |
# |                    |       |         |          |                               |                          |

# %% [markdown]
# Tracetabelle für "EMR":

# %% [markdown]
# | Schleifendurchlauf | index | gesucht | gefunden |        waren                  |          mengen          |
# | ------------------ | ----- | ------- | -------- | ----------------------------- | ------------------------ |
# |                    |       |         |          |                               |                          |
# |                    |       |         |          |                               |                          |
# |                    |       |         |          |                               |                          |
# |                    |       |         |          |                               |                          |
# |                    |       |         |          |                               |                          |
# |                    |       |         |          |                               |                          |
# |                    |       |         |          |                               |                          |
# |                    |       |         |          |                               |                          |
# |                    |       |         |          |                               |                          |
